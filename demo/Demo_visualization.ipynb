# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../batteryratecap')
import visualization

# %%
matplotlib.rcParams.update({'font.size': 20})
pd.set_option('display.max_columns', None)

# %%
Battery_Parameter = pd.read_excel('../doc/data/input_parameterlog.xls', sheet_name=None)
Battery_Parameter_sheet_names = pd.ExcelFile('../doc/data/input_parameterlog.xls').sheet_names
Battery_Parameter_sheet_names
for i, j in enumerate(Battery_Parameter_sheet_names):
    globals()[f'Battery_Parameter_{j}'] = Battery_Parameter[Battery_Parameter_sheet_names[i]]

# %% [markdown]
# ###### Preview pandas dataframes

# %%
Battery_Parameter_MaterialParameters
# Out:
#     Paper #  Set     Cathode Material     Anode Material  \
# 0         1    1              LiFePO4            Lithium
# 1         2    1         Lithium foil            Silver
# 2         2    2         Lithium foil            Silver
# 3         2    3         Lithium foil            Silver
# 4         2    4         Lithium foil            Silver
# ..      ...  ...                  ...                ...
# 85       35    8  LiMnO2 on porous Ni  NiSn on porous Ni
# 86       37    1                  LMO  NiSn on porous Ni
# 87       37    2                  LMO  NiSn on porous Ni
# 88       37    3                  LMO  NiSn on porous Ni
# 89       37    4                  LMO  NiSn on porous Ni
#
#                   Electrolyte Material  \
# 0                              Ionogel
# 1          1M LiPF6 in EC:PC:EMC 1:1:3
# 2          1M LiPF6 in EC:PC:EMC 1:1:3
# 3          1M LiPF6 in EC:PC:EMC 1:1:3
# 4          1M LiPF6 in EC:PC:EMC 1:1:3
# ..                                 ...
# 85  1M LiClO4 EC : DEC in 1:1 wt ratio
# 86  1M LiClO4 EC : DEC in 1:1 wt ratio
# 87  1M LiClO4 EC : DEC in 1:1 wt ratio
# 88  1M LiClO4 EC : DEC in 1:1 wt ratio
# 89  1M LiClO4 EC : DEC in 1:1 wt ratio
#
#    Cathode \nParticle Max. \nDiameter [µm]  \
# 0                                      N/R
# 1                                      N/R
# 2                                      N/R
# 3                                      N/R
# 4                                      N/R
# ..                                     ...
# 85                                     N/R
# 86                                     N/R
# 87                                     N/R
# 88                                     N/R
# 89                                     N/R
#
#    Cathode \nParticle Ave.\nDiameter [µm]  \
# 0                                     NaN
# 1                                     N/R
# 2                                     N/R
# 3                                     N/R
# 4                                     N/R
# ..                                    ...
# 85                                    N/R
# 86                                    100
# 87                                    100
# 88                                    100
# 89                                    100
#
#    Cathode \nParticle Min. \nDiameter [µm]  \
# 0                                      NaN
# 1                                      N/R
# 2                                      N/R
# 3                                      N/R
# 4                                      N/R
# ..                                     ...
# 85                                     N/R
# 86                                     N/R
# 87                                     N/R
# 88                                     N/R
# 89                                     N/R
#
#    Anode \nParticle Max. \nDiameter [µm]  \
# 0                                    N/R
# 1                                   0.03
# 2                                   0.03
# 3                                   0.03
# 4                                   0.03
# ..                                   ...
# 85                                   N/R
# 86                                   N/R
# 87                                   N/R
# 88                                   N/R
# 89                                   N/R
#
#    Anode \nParticle Ave. \nDiameter [µm] Anode \nParticle Min. \nDiameter [µm]
# 0                                    NaN                                   NaN
# 1                                    N/R                                  0.05
# 2                                    N/R                                  0.05
# 3                                    N/R                                  0.05
# 4                                    N/R                                  0.05
# ..                                   ...                                   ...
# 85                                   N/R                                   N/R
# 86                                    70                                   N/R
# 87                                    70                                   N/R
# 88                                    70                                   N/R
# 89                                    70                                   N/R
#
# [90 rows x 11 columns]

# %%
Battery_Parameter_GeometryParameters
# Out:
#     Paper #  Set Full Cell \nThickness [µm] Cathode \nThickness [µm]  \
# 0         1    1                        NaN                      500
# 1         2    1                        NaN                      N/R
# 2         2    2                        NaN                      N/R
# 3         2    3                        NaN                      N/R
# 4         2    4                        NaN                      N/R
# ..      ...  ...                        ...                      ...
# 86       36    1                        NaN                      NaN
# 87       37    1                         10                       10
# 88       37    2                         10                       10
# 89       37    3                         10                       10
# 90       37    4                         10                       10
#
#    Anode \nThickness [µm]  Separator \nThickness [µm]
# 0                      N/R                        N/R
# 1                      215                        N/R
# 2                      415                        N/R
# 3                      265                        N/R
# 4                      473                        N/R
# ..                     ...                        ...
# 86                     NaN                        NaN
# 87                      10                        N/R
# 88                      10                        N/R
# 89                      10                        N/R
# 90                      10                        N/R
#
# [91 rows x 6 columns]

# %% [markdown]
# ### Load all Curve fitting parameters

# %%
fit_df = pd.read_excel('../doc/data/export_fitparameters.xlsx')
par_df = fit_df[{'Paper #','Set','n','tau','Qmax'}]

# %%
par_df
# Out:
#           Qmax  Set       tau         n  Paper #
# 0   106.109020    1  0.485641  1.302511        1
# 1   105.112479    1  0.487356  1.171666        1
# 2     0.000000    1  0.000000  0.000000       11
# 3     0.000000    2  0.000000  0.000000       11
# 4     0.000000    3  0.000000  0.000000       11
# 5     0.000000    4  0.000000  0.000000       11
# 6     0.000000    5  0.000000  0.000000       11
# 7     0.000000    6  0.000000  0.000000       11
# 8   153.778365    1  0.947268  2.223919       17
# 9   151.124828    2  0.529848  2.244143       17
# 10  152.606460    3  0.270365  1.884655       17
# 11  196.645928    1  0.000003  0.115141       19
# 12  127.716692    1  0.092302  4.669977       23
# 13  127.906352    2  0.095259  4.526732       23
# 14  135.232040    1  0.034467  2.421714       27
# 15  306.757653    1  0.109881  2.363978       31
# 16  313.641258    2  0.094515  1.402870       31

# %% [markdown]
# ### Plot histograms to show distributions of n and tau
# Figure 2(f) in Tian's paper

# %%
fig = plt.figure(figsize=(16,6))
ax = fig.subplots(nrows=1,ncols=2)

ax[0].hist(par_df['n'].values)
ax[0].set_xlabel('n')
ax[0].set_xlim(0,2.5)
ax[0].set_ylabel('number of cases')
ax[1].hist(par_df['tau'].values)
ax[1].set_xlabel('tau')
ax[1].set_ylabel('number of cases')
# Out:
# Text(0, 0.5, 'number of cases')

# %%
visualization_df = pd.merge(par_df, Battery_Parameter_GeometryParameters, how="outer", on=['Paper #','Set'])
visualization_df.head()
# Out:
#          Qmax  Set       tau         n  Paper # Full Cell \nThickness [µm]  \
# 0  106.109020    1  0.485641  1.302511        1                        NaN
# 1  105.112479    1  0.487356  1.171666        1                        NaN
# 2    0.000000    1  0.000000  0.000000       11                        N/R
# 3    0.000000    2  0.000000  0.000000       11                        N/R
# 4    0.000000    3  0.000000  0.000000       11                        N/R
#
#   Cathode \nThickness [µm] Anode \nThickness [µm]  Separator \nThickness [µm]
# 0                      500                     N/R                        N/R
# 1                      500                     N/R                        N/R
# 2                       60                     N/R                        N/R
# 3                      120                     N/R                        N/R
# 4                      170                     N/R                        N/R

# %%
# Replace NaN values
visualization_df = visualization_df.replace(['N/R'], np.NaN)
visualization_df
visualization_df.to_excel('../doc/data/export_visualization_df.xlsx')

# %% [markdown]
# ### Load Geometry and Material Parameters

# %%
features = list(visualization_df.columns[6:8])
features
# Out:
# ['Cathode \nThickness [µm]', 'Anode \nThickness [µm] ']

# %%
fig = visualization.feature_vs_n_tau_q(visualization_df, features)
fig.suptitle('Fitting Parameters vs Electrode Thicknesses', y=0, fontweight="bold")
plt.tight_layout()
plt.savefig('visualization_example.png', dpi=300)
