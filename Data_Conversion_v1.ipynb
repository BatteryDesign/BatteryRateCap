# %%
import numpy as np
import pandas as pd
import os

import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import sklearn

# %% [markdown]
# ## Case # 1
#
# ### E vs Li (<font color=red>V</font>) vs Capacity (<font color=red>Ah cm<sup>-2</sup></font>) &#8594; Capacity (<font color=red>Ah cm<sup>-2</sup></font>) vs i (<font color=red>$\mu A$ cm <sup>-2</sup></font>)

# %% [markdown]
# #### Use the highest x-value (capacity Ah cm<sup>-2</sup></font>)

# %%
def potential_rate(n):
    """ 
    This function converts potential vs. capacity data to capacity vs c-rate data
    
    Highest x-value (capacity [mAh]) from the charge/discharge graph
    Input: Potential vs Capacity excel file
    Output: Capacity vs c-rate excel file
    
    """
    return;

# %% [markdown]
# ### Entering c-rates

# %%
rates = { "c-rate": [0.5, 1.0, 2.0, 5.0]}

df_rates = pd.DataFrame(rates)

df_rates
# Out:
#    c-rate
# 0     0.5
# 1     1.0
# 2     2.0
# 3     5.0

# %% [markdown]
# ### 1. Uploading excel file with desired data

# %%
df = pd.read_excel('liibattery3d_performancelog.xls', sheet_name = ['1_Discharge (Cover2)', '1_Discharge (1C)', '1_Discharge (2C)', '1_Discharge (5C)'], header = [0,1,2])

df['1_Discharge (Cover2)'].head()
# Out:
#         Paper # 14                   Paper # 31                               \
#             set #8                       set #1                       set #2
#   Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g)
# 0         4.965905    3.759844        13.782550    3.223055         4.955569
# 1        10.669414    3.660817        24.151907    3.169608        15.194221
# 2        16.082465    3.554446        34.211732    3.106782        25.037697
# 3        22.581061    3.496632        44.426323    3.063749        34.018971
# 4        39.715057    3.384521        54.640914    3.034370        43.646897
#
#                     Paper # 32                                           \
#                         set #1                       set #2
#   Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V)
# 0    3.381480         0.357306    1.922179         0.516464    1.856763
# 1    3.369484         2.627373    1.695525         0.629378    1.788188
# 2    3.310078         1.265333    1.831123         2.452121    1.673004
# 3    3.237262         1.719346    1.796435         1.081031    1.752818
# 4    3.195075         1.946353    1.773310         1.419771    1.722501
#
#
#             set #3
#   Capacity (mAh/g) Voltage (V)
# 0         0.480789    1.799430
# 1         0.480789    1.770996
# 2         0.708262    1.735927
# 3         1.163210    1.692518
# 4         2.950503    1.578659

# %% [markdown]
# ### 2. Merging sheets

# %%
sheet_1 = df['1_Discharge (Cover2)']
sheet_2 = df['1_Discharge (1C)']
sheet_3 = df['1_Discharge (2C)']
sheet_4 = df['1_Discharge (5C)']

# Figure out a way to use for loop this

# %%
df_merged = pd.concat([sheet_1,sheet_2,sheet_3,sheet_4], axis = 1)

# %%
df_merged
# Out:
#          Paper # 31                                                Paper # 32  \
#              set #1                       set #2                       set #1
#    Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g)
# 0         13.782550    3.223055         4.955569    3.381480         0.357306
# 1         24.151907    3.169608        15.194221    3.369484         2.627373
# 2         34.211732    3.106782        25.037697    3.310078         1.265333
# 3         44.426323    3.063749        34.018971    3.237262         1.719346
# 4         54.640914    3.034370        43.646897    3.195075         1.946353
# ..              ...         ...              ...         ...              ...
# 56              NaN         NaN              NaN         NaN       154.154324
# 57              NaN         NaN              NaN         NaN        85.423729
# 58              NaN         NaN              NaN         NaN         4.971751
# 59              NaN         NaN              NaN         NaN              NaN
# 60              NaN         NaN              NaN         NaN              NaN
#
#                                                                           ...  \
#                          set #2                       set #3              ...
#    Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V)  ...
# 0     1.922179         0.516464    1.856763         0.480789    1.799430  ...
# 1     1.695525         0.629378    1.788188         0.480789    1.770996  ...
# 2     1.831123         2.452121    1.673004         0.708262    1.735927  ...
# 3     1.796435         1.081031    1.752818         1.163210    1.692518  ...
# 4     1.773310         1.419771    1.722501         2.950503    1.578659  ...
# ..         ...              ...         ...              ...         ...  ...
# 56    1.017402              NaN         NaN              NaN         NaN  ...
# 57    1.541007              NaN         NaN              NaN         NaN  ...
# 58    1.624460              NaN         NaN              NaN         NaN  ...
# 59         NaN              NaN         NaN              NaN         NaN  ...
# 60         NaN              NaN         NaN              NaN         NaN  ...
#
#          Paper # 31                                                Paper # 32  \
#              set #1                       set #2                       set #1
#    Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g)
# 0          4.393380    3.225997         1.111584    3.126072         0.979316
# 1         14.504793    3.181492         4.955569    3.051738         1.521072
# 2         23.997141    3.144436        13.469816    3.006404         7.691062
# 3         34.211732    3.072300        22.954042    2.944872        12.657152
# 4         44.426323    3.012440        32.438267    2.874374        17.623241
# ..              ...         ...              ...         ...              ...
# 56              NaN         NaN              NaN         NaN              NaN
# 57              NaN         NaN              NaN         NaN              NaN
# 58              NaN         NaN              NaN         NaN              NaN
# 59              NaN         NaN              NaN         NaN              NaN
# 60              NaN         NaN              NaN         NaN              NaN
#
#
#                          set #2                       set #3
#    Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V)
# 0     1.704329         0.968118    1.371688         0.207820    1.292306
# 1     1.591049         6.162129    1.307753         2.224753    1.257074
# 2     1.454812        10.227008    1.282705         6.395104    1.227192
# 3     1.433789        15.195193    1.262493        10.717103    1.198693
# 4     1.422489        20.163378    1.245956        15.721523    1.170259
# ..         ...              ...         ...              ...         ...
# 56         NaN              NaN         NaN              NaN         NaN
# 57         NaN              NaN         NaN              NaN         NaN
# 58         NaN              NaN         NaN              NaN         NaN
# 59         NaN              NaN         NaN              NaN         NaN
# 60         NaN              NaN         NaN              NaN         NaN
#
# [61 rows x 36 columns]

# %% [markdown]
# ### 3. Selecting wanted data

# %%
# Program checks if 
# if the data frame does not start with Print # 32 then drop()

# %%
set_1 = (df_merged['Paper # 32', 'set #1'])
set_2 = (df_merged['Paper # 32', 'set #2'])
set_3 = (df_merged['Paper # 32', 'set #3'])
# Out:
# /home/gskl92/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2894: PerformanceWarning: indexing past lexsort depth may impact performance.
#   result = self._run_cell(

# %%
set_1
# Out:
#     Capacity (mAh/g)  Voltage (V)  Capacity (mAh/g)  Voltage (V)  \
# 0           0.516464     1.856763          0.516464     1.726832
# 1           0.629378     1.788188          0.742291     1.699883
# 2           2.452121     1.673004          2.488683     1.614418
# 3           1.081031     1.752818          3.452210     1.564178
# 4           1.419771     1.722501          5.409374     1.532417
# ..               ...          ...               ...          ...
# 56               NaN          NaN               NaN          NaN
# 57               NaN          NaN               NaN          NaN
# 58               NaN          NaN               NaN          NaN
# 59               NaN          NaN               NaN          NaN
# 60               NaN          NaN               NaN          NaN
#
#     Capacity (mAh/g)  Voltage (V)  Capacity (mAh/g)  Voltage (V)
# 0           2.285439     1.573321          0.968118     1.371688
# 1           2.210164     1.542763          6.162129     1.307753
# 2           2.435990     1.508837         10.227008     1.282705
# 3           4.290995     1.480995         15.195193     1.262493
# 4           8.420395     1.459096         20.163378     1.245956
# ..               ...          ...               ...          ...
# 56               NaN          NaN               NaN          NaN
# 57               NaN          NaN               NaN          NaN
# 58               NaN          NaN               NaN          NaN
# 59               NaN          NaN               NaN          NaN
# 60               NaN          NaN               NaN          NaN
#
# [61 rows x 8 columns]

# %%
set_2
# Out:
#     Capacity (mAh/g)  Voltage (V)  Capacity (mAh/g)  Voltage (V)  \
# 0           0.516464     1.856763          0.516464     1.726832
# 1           0.629378     1.788188          0.742291     1.699883
# 2           2.452121     1.673004          2.488683     1.614418
# 3           1.081031     1.752818          3.452210     1.564178
# 4           1.419771     1.722501          5.409374     1.532417
# ..               ...          ...               ...          ...
# 56               NaN          NaN               NaN          NaN
# 57               NaN          NaN               NaN          NaN
# 58               NaN          NaN               NaN          NaN
# 59               NaN          NaN               NaN          NaN
# 60               NaN          NaN               NaN          NaN
#
#     Capacity (mAh/g)  Voltage (V)  Capacity (mAh/g)  Voltage (V)
# 0           2.285439     1.573321          0.968118     1.371688
# 1           2.210164     1.542763          6.162129     1.307753
# 2           2.435990     1.508837         10.227008     1.282705
# 3           4.290995     1.480995         15.195193     1.262493
# 4           8.420395     1.459096         20.163378     1.245956
# ..               ...          ...               ...          ...
# 56               NaN          NaN               NaN          NaN
# 57               NaN          NaN               NaN          NaN
# 58               NaN          NaN               NaN          NaN
# 59               NaN          NaN               NaN          NaN
# 60               NaN          NaN               NaN          NaN
#
# [61 rows x 8 columns]

# %%
set_1_max = set_1["Capacity (mAh/g)"].max(axis =0)
set_2_max = set_2["Capacity (mAh/g)"].max(axis =0)
set_3_max = set_3["Capacity (mAh/g)"].max(axis =0)

# %%
set_1_max
# Out:
# Capacity (mAh/g)    147.303752
# Capacity (mAh/g)    139.399821
# Capacity (mAh/g)    118.804436
# Capacity (mAh/g)     65.780351
# dtype: float64

# %%
set_2_max
# Out:
# Capacity (mAh/g)    147.303752
# Capacity (mAh/g)    139.399821
# Capacity (mAh/g)    118.804436
# Capacity (mAh/g)     65.780351
# dtype: float64

# %%
def highest_cap(caplist):
    max = caplist[0]
    for n in caplist:
        if n > max :
            max = n
    return max

# %%
highest_cap(set_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-0d3f1b4f6c86> in <module>
# ----> 1 highest_cap(set_1)
#
# <ipython-input-33-edc9bcaa2242> in highest_cap(caplist)
#       1 def highest_cap(caplist):
# ----> 2     max = caplist[0]
#       3     for n in caplist:
#       4         if n > max :
#       5             max = n
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0

# %%
df['1_Discharge (Cover2)'].drop('Paper # 14', inplace = True, axis = 1)

# %%
df['1_Discharge (Cover2)'].head()
# Out:
#         Paper # 31                                                Paper # 32  \
#             set #1                       set #2                       set #1
#   Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g)
# 0        13.782550    3.223055         4.955569    3.381480         0.357306
# 1        24.151907    3.169608        15.194221    3.369484         2.627373
# 2        34.211732    3.106782        25.037697    3.310078         1.265333
# 3        44.426323    3.063749        34.018971    3.237262         1.719346
# 4        54.640914    3.034370        43.646897    3.195075         1.946353
#
#
#                         set #2                       set #3
#   Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V)
# 0    1.922179         0.516464    1.856763         0.480789    1.799430
# 1    1.695525         0.629378    1.788188         0.480789    1.770996
# 2    1.831123         2.452121    1.673004         0.708262    1.735927
# 3    1.796435         1.081031    1.752818         1.163210    1.692518
# 4    1.773310         1.419771    1.722501         2.950503    1.578659

# %%
df.filter(items = ['Paper # 32'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-8438482a5e27> in <module>
# ----> 1 df.filter(items = ['Paper # 32'])
#
# AttributeError: 'dict' object has no attribute 'filter'

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
df1 = pd.read_excel('liibattery3d_performancelog.xls', sheet_name = '1_Discharge (Cover2)', header = [0,1,2])

df1.head()
# Out:
#         Paper # 14                   Paper # 31                               \
#             set #8                       set #1                       set #2
#   Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g)
# 0         4.965905    3.759844        13.782550    3.223055         4.955569
# 1        10.669414    3.660817        24.151907    3.169608        15.194221
# 2        16.082465    3.554446        34.211732    3.106782        25.037697
# 3        22.581061    3.496632        44.426323    3.063749        34.018971
# 4        39.715057    3.384521        54.640914    3.034370        43.646897
#
#                     Paper # 32                                           \
#                         set #1                       set #2
#   Voltage (V) Capacity (mAh/g) Voltage (V) Capacity (mAh/g) Voltage (V)
# 0    3.381480         0.357306    1.922179         0.516464    1.856763
# 1    3.369484         2.627373    1.695525         0.629378    1.788188
# 2    3.310078         1.265333    1.831123         2.452121    1.673004
# 3    3.237262         1.719346    1.796435         1.081031    1.752818
# 4    3.195075         1.946353    1.773310         1.419771    1.722501
#
#
#             set #3
#   Capacity (mAh/g) Voltage (V)
# 0         0.480789    1.799430
# 1         0.480789    1.770996
# 2         0.708262    1.735927
# 3         1.163210    1.692518
# 4         2.950503    1.578659

# %%
x1 = df1.iloc[:,0]
y1 = df1.iloc[:,1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1ff76015e047> in <module>
# ----> 1 x1 = df1.iloc[:,0]
#       2 y1 = df1.iloc[:,1]
#
# AttributeError: 'dict' object has no attribute 'iloc'

# %%
matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(20, 5))


plt.scatter(x1,y1)

# %%
def highest_cap(caplist):
    max = caplist[0]
    for n in caplist:
        if n > max :
            max = n
    return max

# %%
highest_cap(x1) #Need iterations for this
# Out:
# 114.70562632388346

# %% [markdown]
# ## Case # 2
#
# ### Capacity (<font color=red>Ah cm<sup>-2</sup></font>) vs Cycle &#8594; Capacity (<font color=red>Ah cm<sup>-2</sup></font>) vs i (<font color=red>$\mu A$ cm <sup>-2</sup></font>)

# %% [markdown]
# #### Current density has to be entered separately, cannot be calculated with the amount of information given from the capacity data online

# %%
def Cycle_rate(n):
    
    """ 
    This function converts capacity vs. cycle data to capacity vs c-rate
    
    Average the x-values (capacity [mAh]) of corresponding current density from the charge/discharge graph
    Input: Capacity vs Cycle excel file
    Output: Capacity vs c-rate excel file
    
    """
    
    return;

# %%
path = "3D_Battery_Performance_Log.xlsx"
file_name = os.path.abspath(path)

print(file_name)

# %%
df2 = pd.read_excel('3D_Battery_Performance_Log.xls', sheet_name = '4_CapacityCycle', header = [0,1,2])

# %%
df2.head()
# Out:
#   Paper # 1                  Paper # 2                             \
#    Set #1 E                   Set #1 E                   Set #2 E
#     Cycle # Capacity (mAh/g)   Cycle # Capacity (mAh/g)   Cycle #
# 0  0.185615       122.911465  1.021898       249.145299  0.948905
# 1  1.670534       127.179225  1.897810       197.863248  2.043796
# 2  2.969838       119.497258  3.065693       199.572650  2.992701
# 3  3.897912       110.961740  4.014599       214.957265  3.868613
# 4  5.011601       109.681412  4.963504       261.965812  4.963504
#
#                                                                           ...  \
#                     Set #3 E                   Set #4 E                   ...
#   Capacity (mAh/g)   Cycle # Capacity (mAh/g)   Cycle # Capacity (mAh/g)  ...
# 0       150.000000  0.912162        70.588235  0.979730        84.873950  ...
# 1       129.487179  1.925676        36.554622  1.858108        40.336134  ...
# 2       124.358974  3.006757        35.714286  2.939189        42.016807  ...
# 3       127.777778  3.885135        35.714286  4.020270        43.277311  ...
# 4       130.341880  4.898649        35.294118  4.898649        40.336134  ...
#
#   Paper #29                  Paper #32                              \
#    Set #1 E                   Set #1 E                    Set #2 E
#     Cycle # Capacity (mAh/g)   Cycle # Capacity (mAh/g)    Cycle #
# 0  1.008547       117.083333  0.970927       173.078008  12.054231
# 1  2.017094        96.250000  2.000792       159.745980  13.035055
# 2  3.008547       101.805556  3.030656       157.778195  14.064919
# 3  4.034188       104.583333  3.962438       157.708333  15.045742
# 4  4.991453       105.972222  5.074038       156.485746  19.067118
#
#
#                     Set #3 E
#   Capacity (mAh/g)   Cycle # Capacity (mAh/g) Cycle #.1 Capacity (mAh/g).1
# 0       135.951262  0.970927       158.406955       NaN                NaN
# 1       135.402345  2.000792       149.848841       NaN                NaN
# 2       135.527099  2.981615       148.800909       NaN                NaN
# 3       135.585317  3.962438       148.509816       NaN                NaN
# 4       116.547880  4.992303       147.857769       NaN                NaN
#
# [5 rows x 30 columns]

# %%
df2['Paper # 1']['Set #1 E'].head()

# %%
df = pd.read_excel('Paper_99_data.xls', sheet_name = 'CapacityCycle', header = [0,1,2])

# %%
df.head()
# Out:
#   Paper #1
#     Set #1
#    Cycle # Ch. Cap. Dis. Cap. Ch. Cap. (mAh/g) Dis. Cap. (mAh/g)
# 0        1   0.3906    0.7152       441.855204        809.049774
# 1        2   0.4024    0.4335       455.203620        490.384615
# 2        3   0.4080    0.4260       461.538462        481.900452
# 3        4   0.4097    0.4229       463.461538        478.393665
# 4        5   0.4101    0.4210       463.914027        476.244344

# %%
x = df.iloc[:,0]
y = df.iloc[:,4]

matplotlib.rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(20, 5))


plt.scatter(x,y)

# %%
df.iloc[:5,0]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: (Paper #1, Set #1, Cycle #), dtype: int64

# %%
c_rate = [1, 2, 4, 8, 20, 8, 4, 2, 1]

# %%
def groupedAvg(AvgCap, N=10):
    result = np.cumsum(AvgCap)[0:N-1]/float(N)
    return result

# %%
groupedAvg(y, N=10) #I'm not sure why it's showing smallest to largest
# Out:
# 0     80.904977
# 1    129.943439
# 2    178.133484
# 3    225.972851
# 4    273.597285
# 5    321.029412
# 6    368.280543
# 7    415.384615
# 8    462.352941
# Name: (Paper #1, Set #1, Dis. Cap. (mAh/g)), dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f00663e8be01> in <module>
# ----> 1 groupAvg.head()
#
# NameError: name 'groupAvg' is not defined
